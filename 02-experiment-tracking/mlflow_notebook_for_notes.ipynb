# %% [markdown]
# ## Import libraries

# %%
import pandas as pd

from sklearn.feature_extraction import DictVectorizer
from sklearn.linear_model import Lasso, ElasticNet
from sklearn.metrics import mean_squared_error

from sklearn.ensemble import GradientBoostingRegressor

import pickle

# %%
# !python -V
# Out:
# Python 3.9.12

# %% [markdown]
# #### Import MLflow

# %%
import mlflow

# %%
# We need to set tracking URI to point the library to the SQLite backend database for MLFlow
mlflow.set_tracking_uri("sqlite:///mlflow.db")

# %%
# We also need to set the experiment. MLflow will create one if it doesn't exist
mlflow.set_experiment("nyc-taxi-experiment")
# Out:
# <Experiment: artifact_location='./mlruns/2', experiment_id='2', lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>

# %% [markdown]
# ### Data and Modeling

# %%
# read Jan 2021 FHV data 
df = pd.read_parquet("data/fhv_tripdata_2021-01.parquet")

# %%
print("Number of Records in Jan 2021 FHV data:", len(df))
# Out:
# Number of Records in Jan 2021 FHV data: 1154112

# %%
# let's check out the columns in the df
df.head()
# Out:
#   dispatching_base_num     pickup_datetime    dropOff_datetime  PUlocationID  \
# 0               B00009 2021-01-01 00:27:00 2021-01-01 00:44:00           NaN
# 1               B00009 2021-01-01 00:50:00 2021-01-01 01:07:00           NaN
# 2               B00013 2021-01-01 00:01:00 2021-01-01 01:51:00           NaN
# 3               B00037 2021-01-01 00:13:09 2021-01-01 00:21:26           NaN
# 4               B00037 2021-01-01 00:38:31 2021-01-01 00:53:44           NaN
#
#    DOlocationID  SR_Flag Affiliated_base_number
# 0           NaN      NaN                 B00009
# 1           NaN      NaN                 B00009
# 2           NaN      NaN                 B00013
# 3          72.0      NaN                 B00037
# 4          61.0      NaN                 B00037

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1154112 entries, 0 to 1154111
# Data columns (total 7 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   dispatching_base_num    1154112 non-null  object
#  1   pickup_datetime         1154112 non-null  datetime64[ns]
#  2   dropOff_datetime        1154112 non-null  datetime64[ns]
#  3   PUlocationID            195845 non-null   float64
#  4   DOlocationID            991892 non-null   float64
#  5   SR_Flag                 0 non-null        float64
#  6   Affiliated_base_number  1153227 non-null  object
# dtypes: datetime64[ns](2), float64(3), object(2)
# memory usage: 61.6+ MB

# %%
# let's calculate duration of each trip
df["duration"] = df["dropOff_datetime"] - df["pickup_datetime"]
df.head()
# Out:
#   dispatching_base_num     pickup_datetime    dropOff_datetime  PUlocationID  \
# 0               B00009 2021-01-01 00:27:00 2021-01-01 00:44:00           NaN
# 1               B00009 2021-01-01 00:50:00 2021-01-01 01:07:00           NaN
# 2               B00013 2021-01-01 00:01:00 2021-01-01 01:51:00           NaN
# 3               B00037 2021-01-01 00:13:09 2021-01-01 00:21:26           NaN
# 4               B00037 2021-01-01 00:38:31 2021-01-01 00:53:44           NaN
#
#    DOlocationID  SR_Flag Affiliated_base_number        duration
# 0           NaN      NaN                 B00009 0 days 00:17:00
# 1           NaN      NaN                 B00009 0 days 00:17:00
# 2           NaN      NaN                 B00013 0 days 01:50:00
# 3          72.0      NaN                 B00037 0 days 00:08:17
# 4          61.0      NaN                 B00037 0 days 00:15:13

# %%
# convert duration into minutes
df["duration"] = df["duration"].apply(lambda x: x.total_seconds() / 60)
df.head()
# Out:
#   dispatching_base_num     pickup_datetime    dropOff_datetime  PUlocationID  \
# 0               B00009 2021-01-01 00:27:00 2021-01-01 00:44:00           NaN
# 1               B00009 2021-01-01 00:50:00 2021-01-01 01:07:00           NaN
# 2               B00013 2021-01-01 00:01:00 2021-01-01 01:51:00           NaN
# 3               B00037 2021-01-01 00:13:09 2021-01-01 00:21:26           NaN
# 4               B00037 2021-01-01 00:38:31 2021-01-01 00:53:44           NaN
#
#    DOlocationID  SR_Flag Affiliated_base_number    duration
# 0           NaN      NaN                 B00009   17.000000
# 1           NaN      NaN                 B00009   17.000000
# 2           NaN      NaN                 B00013  110.000000
# 3          72.0      NaN                 B00037    8.283333
# 4          61.0      NaN                 B00037   15.216667

# %%
print("Average duration in Jan 2021 FHV:", round(df["duration"].mean(),2))
# Out:
# Average duration in Jan 2021 FHV: 19.17

# %%
print(f"Fractions of missing values of the pickup location ID: {round(df.PUlocationID.isnull().mean()*100, 2)}%")
# Out:
# Fractions of missing values of the pickup location ID: 83.03%

# %%
df["PUlocationID"].fillna("-1", inplace=True)
df["DOlocationID"].fillna("-1", inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1154112 entries, 0 to 1154111
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count    Dtype
# ---  ------                  --------------    -----
#  0   dispatching_base_num    1154112 non-null  object
#  1   pickup_datetime         1154112 non-null  datetime64[ns]
#  2   dropOff_datetime        1154112 non-null  datetime64[ns]
#  3   PUlocationID            1154112 non-null  object
#  4   DOlocationID            1154112 non-null  object
#  5   SR_Flag                 0 non-null        float64
#  6   Affiliated_base_number  1153227 non-null  object
#  7   duration                1154112 non-null  float64
# dtypes: datetime64[ns](2), float64(2), object(4)
# memory usage: 70.4+ MB

# %%
df["duration"].describe()
# Out:
# count    1.154112e+06
# mean     1.916722e+01
# std      3.986922e+02
# min      1.666667e-02
# 25%      7.766667e+00
# 50%      1.340000e+01
# 75%      2.228333e+01
# max      4.233710e+05
# Name: duration, dtype: float64

# %%
df["duration"].describe(percentiles=[0.25, 0.90, 0.95, 0.98, 0.99])
# Out:
# count    1.154112e+06
# mean     1.916722e+01
# std      3.986922e+02
# min      1.666667e-02
# 25%      7.766667e+00
# 50%      1.340000e+01
# 90%      3.563333e+01
# 95%      4.725000e+01
# 98%      6.613333e+01
# 99%      9.030000e+01
# max      4.233710e+05
# Name: duration, dtype: float64

# %% [markdown]
# Maximum trip is 42,337 minutes, equivalent to 294 days and minimum is 0.017 minutes. Let's filter down the data to be more than 4 mins and less than 95 mins

# %%
print("Total % records for filtered data: {}%".format(round(((df["duration"] >= 4) & (df["duration"] <= 95)).mean()*100, 2)))
# Out:
# Total % records for filtered data: 90.44%

# %%
df["duration"].describe(percentiles=[0.95, 0.98, 0.99])
# Out:
# count    1.154112e+06
# mean     1.916722e+01
# std      3.986922e+02
# min      1.666667e-02
# 50%      1.340000e+01
# 95%      4.725000e+01
# 98%      6.613333e+01
# 99%      9.030000e+01
# max      4.233710e+05
# Name: duration, dtype: float64

# %% [markdown]
# ### Pulling input_data together

# %%
def read_data(file:str):
    df = pd.read_parquet(file)
    print("Number of Records in data:", len(df))
    
    # get duration
    df["duration"] = df["dropOff_datetime"] - df["pickup_datetime"]
    # convert duration to minutes
    df["duration"] = df["duration"].apply(lambda x: x.total_seconds() / 60)
    print("Average duration in data:", round(df["duration"].mean(),2))
    print(f"Fractions of missing values of the pickup location ID: {round(sum(df.PUlocationID.isnull())/len(df.PUlocationID)*100, 2)}%")

    # fill na
    df["PUlocationID"].fillna("-1", inplace=True)
    df["DOlocationID"].fillna("-1", inplace=True)

    df[['PUlocationID', 'DOlocationID']] = df[['PUlocationID', 'DOlocationID']].astype(str)
    df['PU_DO'] = df['PUlocationID'] + '_' + df['DOlocationID']

    df = df[(df["duration"] >= 4) & (df["duration"] <= 95)]

    return df

# %%
df_train = read_data("data/fhv_tripdata_2021-01.parquet")
# Out:
# Number of Records in data: 1154112
# Average duration in data: 19.17
# Fractions of missing values of the pickup location ID: 83.03%

# %% [markdown]
# ### One-hot encoding

# %%
# lets extrain X_train data in dictionary form
X_train_dict = df_train[["PUlocationID", "DOlocationID"]].to_dict(orient="records")

# %%
# initialize vectorizer 
dv = DictVectorizer()

# one-hot encoding
X_train = dv.fit_transform(X_train_dict)

# %%
print("Dimensionality of X_train:", X_train.shape)
# Out:
# Dimensionality of X_train: (1043765, 525)

# %%
# target variable
y_train = df_train["duration"]

# %% [markdown]
# ### Fit the model!

# %%
df_val = read_data("./data/fhv_tripdata_2021-02.parquet")

# lets extrain X_train data in dictionary form
X_val_dict = df_val[["PU_DO"]].to_dict(orient="records")

# one-hot encoding
X_val = dv.transform(X_val_dict)

# y_val
y_val = df_val["duration"]
# Out:
# Number of Records in data: 1037692
# Average duration in data: 20.71
# Fractions of missing values of the pickup location ID: 85.26%

# %%
# start logging with mlflow
with mlflow.start_run():
    # set tag for mlflow
    mlflow.set_tag("developer", "Bengsoon")
    mlflow.set_tag("model", "linear_regression")

    # set data path param
    mlflow.log_param("train-data-path", "./data/fhv_tripdata_2021-01.parquet")
    mlflow.log_param("valid-data-path", "./data/fhv_tripdata_2021-02.parquet")

    # set hyper parameter for Lasso
    alpha = 0.01
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha = alpha)
    
    # train the model
    lr.fit(X_train, y_train)

    # get the y_pred from X_train
    y_pred = lr.predict(X_val)

    # get RMSE and record on mlflow
    rmse = round(mean_squared_error(y_val, y_pred, squared=False),2)
    print("RMSE for training data:", rmse)
    mlflow.log_metric("rmse", rmse)
# Out:
# RMSE for training data: 14.51

# %% [markdown]
# ### Hyperparameter Tuning with XGBoost and hyperopt

# %%
import xgboost as xgb

from hyperopt import fmin, tpe, hp, STATUS_OK, Trials
from hyperopt.pyll import scope

train = xgb.DMatrix(X_train, label=y_train)
valid = xgb.DMatrix(X_val, label=y_val)

# %%
# create an objective function that trains the xgboost model with a set of hyperparameters (from hyperopt) and then validated against our validation data. 
## for each set of hyperparameters and the model's corresponding performance score, we record them in mlflow 
def objective(params):
    with mlflow.start_run():
        mlflow.set_tag("model", "xgboost")
        mlflow.log_params(params)
        booster = xgb.train(
            params=params,
            dtrain=train,
            num_boost_round=1000,
            evals=[(valid, 'validation')],
            early_stopping_rounds=50
        )
        y_pred = booster.predict(valid)
        rmse = mean_squared_error(y_val, y_pred, squared=False)
        mlflow.log_metric("rmse", rmse)

    return {'loss': rmse, 'status': STATUS_OK}

# %%
# create search space for our XGBoost hyperparameters
search_space = {
    'max_depth': scope.int(hp.quniform('max_depth', 4, 100, 1)),
    'learning_rate': hp.loguniform('learning_rate', -3, 0),
    'reg_alpha': hp.loguniform('reg_alpha', -5, -1),
    'reg_lambda': hp.loguniform('reg_lambda', -6, -1),
    'min_child_weight': hp.loguniform('min_child_weight', -1, 3),
    'objective': 'reg:linear',
    'seed': 42
}

# %%
# run the hyperopt optimization
best_result = fmin(
    fn=objective,
    space=search_space,
    algo=tpe.suggest,
    max_evals=50,
    trials=Trials()
)
# Out:
# [17:44:13] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:20.79160
# [1]	validation-rmse:18.41274
# [2]	validation-rmse:17.00143
# [3]	validation-rmse:15.83355
# [4]	validation-rmse:15.25739
# [5]	validation-rmse:14.79529
# [6]	validation-rmse:14.61999
# [7]	validation-rmse:14.51805
# [8]	validation-rmse:14.46920
# [9]	validation-rmse:14.44403
# [10]	validation-rmse:14.42998
# [11]	validation-rmse:14.43086
# [12]	validation-rmse:14.43444
# [13]	validation-rmse:14.44042
# [14]	validation-rmse:14.44777
# [15]	validation-rmse:14.45262
# [16]	validation-rmse:14.45624
# [17]	validation-rmse:14.46003
# [18]	validation-rmse:14.47054
# [19]	validation-rmse:14.47337
# [20]	validation-rmse:14.47805
# [21]	validation-rmse:14.47970
# [22]	validation-rmse:14.48056
# [23]	validation-rmse:14.48198
# [24]	validation-rmse:14.48477
# [25]	validation-rmse:14.48514
# [26]	validation-rmse:14.48610
# [27]	validation-rmse:14.48551
# [28]	validation-rmse:14.48036
# [29]	validation-rmse:14.48000
# [30]	validation-rmse:14.48042
# [31]	validation-rmse:14.48059
# [32]	validation-rmse:14.48068
# [33]	validation-rmse:14.48056
# [34]	validation-rmse:14.48029
# [35]	validation-rmse:14.48002
# [36]	validation-rmse:14.47851
# [37]	validation-rmse:14.47575
# [38]	validation-rmse:14.47536
# [39]	validation-rmse:14.47431
# [40]	validation-rmse:14.47363
# [41]	validation-rmse:14.47330
# [42]	validation-rmse:14.47293
# [43]	validation-rmse:14.47271
# [44]	validation-rmse:14.47278
# [45]	validation-rmse:14.47249
# [46]	validation-rmse:14.47169
# [47]	validation-rmse:14.47171
# [48]	validation-rmse:14.47152
# [49]	validation-rmse:14.47144
# [50]	validation-rmse:14.47007
# [51]	validation-rmse:14.47013
# [52]	validation-rmse:14.46996
# [53]	validation-rmse:14.46969
# [54]	validation-rmse:14.46966
# [55]	validation-rmse:14.46959
# [56]	validation-rmse:14.46956
# [57]	validation-rmse:14.46947
# [58]	validation-rmse:14.46910
# [59]	validation-rmse:14.46896
# [17:47:06] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:22.76469
# [1]	validation-rmse:21.89537
# [2]	validation-rmse:21.00417
# [3]	validation-rmse:20.29168
# [4]	validation-rmse:19.55135
# [5]	validation-rmse:18.98419
# [6]	validation-rmse:18.34076
# [7]	validation-rmse:17.88352
# [8]	validation-rmse:17.36446
# [9]	validation-rmse:17.01202
# [10]	validation-rmse:16.69619
# [11]	validation-rmse:16.32041
# [12]	validation-rmse:15.99810
# [13]	validation-rmse:15.73033
# [14]	validation-rmse:15.54917
# [15]	validation-rmse:15.33728
# [16]	validation-rmse:15.20472
# [17]	validation-rmse:15.04794
# [18]	validation-rmse:14.91293
# [19]	validation-rmse:14.83277
# [20]	validation-rmse:14.73989
# [21]	validation-rmse:14.68489
# [22]	validation-rmse:14.62610
# [23]	validation-rmse:14.58641
# [24]	validation-rmse:14.53892
# [25]	validation-rmse:14.51344
# [26]	validation-rmse:14.49120
# [27]	validation-rmse:14.47539
# [28]	validation-rmse:14.45637
# [29]	validation-rmse:14.44747
# [30]	validation-rmse:14.44083
# [31]	validation-rmse:14.43618
# [32]	validation-rmse:14.43302
# [33]	validation-rmse:14.43093
# [34]	validation-rmse:14.42995
# [35]	validation-rmse:14.42974
# [36]	validation-rmse:14.43018
# [37]	validation-rmse:14.43110
# [38]	validation-rmse:14.43403
# [39]	validation-rmse:14.43817
# [40]	validation-rmse:14.44060
# [41]	validation-rmse:14.44310
# [42]	validation-rmse:14.44583
# [43]	validation-rmse:14.44829
# [44]	validation-rmse:14.45114
# [45]	validation-rmse:14.45367
# [46]	validation-rmse:14.45993
# [47]	validation-rmse:14.46276
# [48]	validation-rmse:14.46530
# [49]	validation-rmse:14.46845
# [50]	validation-rmse:14.47433
# [51]	validation-rmse:14.47634
# [52]	validation-rmse:14.47869
# [53]	validation-rmse:14.48130
# [54]	validation-rmse:14.48392
# [55]	validation-rmse:14.48672
# [56]	validation-rmse:14.48852
# [57]	validation-rmse:14.49266
# [58]	validation-rmse:14.49402
# [59]	validation-rmse:14.49627
# [60]	validation-rmse:14.49825
# [61]	validation-rmse:14.50267
# [62]	validation-rmse:14.50396
# [63]	validation-rmse:14.50506
# [64]	validation-rmse:14.50607
# [65]	validation-rmse:14.50971
# [66]	validation-rmse:14.51078
# [67]	validation-rmse:14.51396
# [68]	validation-rmse:14.51438
# [69]	validation-rmse:14.51535
# [70]	validation-rmse:14.51588
# [71]	validation-rmse:14.51800
# [72]	validation-rmse:14.52053
# [73]	validation-rmse:14.52114
# [74]	validation-rmse:14.52201
# [75]	validation-rmse:14.52372
# [76]	validation-rmse:14.52449
# [77]	validation-rmse:14.52443
# [78]	validation-rmse:14.52463
# [79]	validation-rmse:14.52589
# [80]	validation-rmse:14.52616
# [81]	validation-rmse:14.52609
# [82]	validation-rmse:14.52621
# [83]	validation-rmse:14.52722
# [84]	validation-rmse:14.52761
# [85]	validation-rmse:14.52802
# [17:55:49] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:15.85049
# [1]	validation-rmse:14.52224
# [2]	validation-rmse:14.42996
# [3]	validation-rmse:14.44149
# [4]	validation-rmse:14.45613
# [5]	validation-rmse:14.45682
# [6]	validation-rmse:14.46439
# [7]	validation-rmse:14.46275
# [8]	validation-rmse:14.46554
# [9]	validation-rmse:14.46180
# [10]	validation-rmse:14.46408
# [11]	validation-rmse:14.46377
# [12]	validation-rmse:14.46251
# [13]	validation-rmse:14.46313
# [14]	validation-rmse:14.46479
# [15]	validation-rmse:14.46355
# [16]	validation-rmse:14.46615
# [17]	validation-rmse:14.46458
# [18]	validation-rmse:14.46258
# [19]	validation-rmse:14.46514
# [20]	validation-rmse:14.46463
# [21]	validation-rmse:14.46344
# [22]	validation-rmse:14.46306
# [23]	validation-rmse:14.46245
# [24]	validation-rmse:14.45991
# [25]	validation-rmse:14.45892
# [26]	validation-rmse:14.45837
# [27]	validation-rmse:14.45887
# [28]	validation-rmse:14.45998
# [29]	validation-rmse:14.45876
# [30]	validation-rmse:14.45927
# [31]	validation-rmse:14.45902
# [32]	validation-rmse:14.46074
# [33]	validation-rmse:14.46110
# [34]	validation-rmse:14.46161
# [35]	validation-rmse:14.46254
# [36]	validation-rmse:14.46222
# [37]	validation-rmse:14.46199
# [38]	validation-rmse:14.46129
# [39]	validation-rmse:14.46096
# [40]	validation-rmse:14.46089
# [41]	validation-rmse:14.46029
# [42]	validation-rmse:14.46001
# [43]	validation-rmse:14.45956
# [44]	validation-rmse:14.45944
# [45]	validation-rmse:14.45944
# [46]	validation-rmse:14.45888
# [47]	validation-rmse:14.45944
# [48]	validation-rmse:14.46041
# [49]	validation-rmse:14.46007
# [50]	validation-rmse:14.46031
# [51]	validation-rmse:14.46023
# [17:56:11] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:21.87745
# [1]	validation-rmse:20.29543
# [2]	validation-rmse:18.85823
# [3]	validation-rmse:17.88440
# [4]	validation-rmse:16.91451
# [5]	validation-rmse:16.31655
# [6]	validation-rmse:15.71858
# [7]	validation-rmse:15.37130
# [8]	validation-rmse:15.03232
# [9]	validation-rmse:14.84955
# [10]	validation-rmse:14.71652
# [11]	validation-rmse:14.61960
# [12]	validation-rmse:14.55467
# [13]	validation-rmse:14.51162
# [14]	validation-rmse:14.46213
# [15]	validation-rmse:14.44613
# [16]	validation-rmse:14.43618
# [17]	validation-rmse:14.43152
# [18]	validation-rmse:14.42980
# [19]	validation-rmse:14.43013
# [20]	validation-rmse:14.43503
# [21]	validation-rmse:14.43885
# [22]	validation-rmse:14.44863
# [23]	validation-rmse:14.45381
# [24]	validation-rmse:14.45721
# [25]	validation-rmse:14.46635
# [26]	validation-rmse:14.47140
# [27]	validation-rmse:14.47509
# [28]	validation-rmse:14.47756
# [29]	validation-rmse:14.48142
# [30]	validation-rmse:14.48495
# [31]	validation-rmse:14.48723
# [32]	validation-rmse:14.49405
# [33]	validation-rmse:14.49571
# [34]	validation-rmse:14.49919
# [35]	validation-rmse:14.49964
# [36]	validation-rmse:14.50069
# [37]	validation-rmse:14.50270
# [38]	validation-rmse:14.50356
# [39]	validation-rmse:14.50621
# [40]	validation-rmse:14.50693
# [41]	validation-rmse:14.50773
# [42]	validation-rmse:14.50838
# [43]	validation-rmse:14.50870
# [44]	validation-rmse:14.50918
# [45]	validation-rmse:14.50877
# [46]	validation-rmse:14.50887
# [47]	validation-rmse:14.50934
# [48]	validation-rmse:14.50848
# [49]	validation-rmse:14.50888
# [50]	validation-rmse:14.50726
# [51]	validation-rmse:14.50723
# [52]	validation-rmse:14.50736
# [53]	validation-rmse:14.50817
# [54]	validation-rmse:14.50810
# [55]	validation-rmse:14.50793
# [56]	validation-rmse:14.50795
# [57]	validation-rmse:14.50786
# [58]	validation-rmse:14.50728
# [59]	validation-rmse:14.50713
# [60]	validation-rmse:14.50689
# [61]	validation-rmse:14.50639
# [62]	validation-rmse:14.50562
# [63]	validation-rmse:14.50525
# [64]	validation-rmse:14.50503
# [65]	validation-rmse:14.50477
# [66]	validation-rmse:14.50467
# [67]	validation-rmse:14.50438
# [68]	validation-rmse:14.50317
# [18:00:52] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:22.50670
# [1]	validation-rmse:21.37985
# [2]	validation-rmse:20.41868
# [3]	validation-rmse:19.49273
# [4]	validation-rmse:18.73143
# [5]	validation-rmse:18.08871
# [6]	validation-rmse:17.43797
# [7]	validation-rmse:16.95314
# [8]	validation-rmse:16.46987
# [9]	validation-rmse:16.05952
# [10]	validation-rmse:15.76773
# [11]	validation-rmse:15.52779
# [12]	validation-rmse:15.27285
# [13]	validation-rmse:15.11356
# [14]	validation-rmse:14.93464
# [15]	validation-rmse:14.83773
# [16]	validation-rmse:14.74977
# [17]	validation-rmse:14.68433
# [18]	validation-rmse:14.62907
# [19]	validation-rmse:14.58699
# [20]	validation-rmse:14.55258
# [21]	validation-rmse:14.50656
# [22]	validation-rmse:14.48630
# [23]	validation-rmse:14.47015
# [24]	validation-rmse:14.44994
# [25]	validation-rmse:14.44232
# [26]	validation-rmse:14.43692
# [27]	validation-rmse:14.43314
# [28]	validation-rmse:14.43093
# [29]	validation-rmse:14.42977
# [30]	validation-rmse:14.43040
# [31]	validation-rmse:14.43172
# [32]	validation-rmse:14.43352
# [33]	validation-rmse:14.43855
# [34]	validation-rmse:14.44183
# [35]	validation-rmse:14.44459
# [36]	validation-rmse:14.45125
# [37]	validation-rmse:14.45386
# [38]	validation-rmse:14.45715
# [39]	validation-rmse:14.45968
# [40]	validation-rmse:14.46226
# [41]	validation-rmse:14.46956
# [42]	validation-rmse:14.47167
# [43]	validation-rmse:14.47422
# [44]	validation-rmse:14.47880
# [45]	validation-rmse:14.48041
# [46]	validation-rmse:14.48242
# [47]	validation-rmse:14.48517
# [48]	validation-rmse:14.48631
# [49]	validation-rmse:14.48796
# [50]	validation-rmse:14.49172
# [51]	validation-rmse:14.49284
# [52]	validation-rmse:14.49408
# [53]	validation-rmse:14.49702
# [54]	validation-rmse:14.49792
# [55]	validation-rmse:14.49887
# [56]	validation-rmse:14.49971
# [57]	validation-rmse:14.50185
# [58]	validation-rmse:14.50275
# [59]	validation-rmse:14.50312
# [60]	validation-rmse:14.50390
# [61]	validation-rmse:14.50444
# [62]	validation-rmse:14.50492
# [63]	validation-rmse:14.50679
# [64]	validation-rmse:14.50724
# [65]	validation-rmse:14.50735
# [66]	validation-rmse:14.50772
# [67]	validation-rmse:14.50810
# [68]	validation-rmse:14.50821
# [69]	validation-rmse:14.50946
# [70]	validation-rmse:14.50960
# [71]	validation-rmse:14.50954
# [72]	validation-rmse:14.50966
# [73]	validation-rmse:14.50969
# [74]	validation-rmse:14.50990
# [75]	validation-rmse:14.51077
# [76]	validation-rmse:14.51037
# [77]	validation-rmse:14.50968
# [78]	validation-rmse:14.50973
# [79]	validation-rmse:14.50950
# [18:04:21] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:19.83704
# [1]	validation-rmse:17.26527
# [2]	validation-rmse:15.91048
# [3]	validation-rmse:15.18881
# [4]	validation-rmse:14.68691
# [5]	validation-rmse:14.53643
# [6]	validation-rmse:14.46539
# [7]	validation-rmse:14.43853
# [8]	validation-rmse:14.43266
# [9]	validation-rmse:14.44041
# [10]	validation-rmse:14.44831
# [11]	validation-rmse:14.45578
# [12]	validation-rmse:14.46933
# [13]	validation-rmse:14.47453
# [14]	validation-rmse:14.47786
# [15]	validation-rmse:14.48123
# [16]	validation-rmse:14.48341
# [17]	validation-rmse:14.48494
# [18]	validation-rmse:14.48983
# [19]	validation-rmse:14.48938
# [20]	validation-rmse:14.48954
# [21]	validation-rmse:14.48808
# [22]	validation-rmse:14.48814
# [23]	validation-rmse:14.48759
# [24]	validation-rmse:14.48727
# [25]	validation-rmse:14.48652
# [26]	validation-rmse:14.48769
# [27]	validation-rmse:14.48691
# [28]	validation-rmse:14.48348
# [29]	validation-rmse:14.48096
# [30]	validation-rmse:14.48010
# [31]	validation-rmse:14.48072
# [32]	validation-rmse:14.48008
# [33]	validation-rmse:14.47959
# [34]	validation-rmse:14.47926
# [35]	validation-rmse:14.47474
# [36]	validation-rmse:14.47388
# [37]	validation-rmse:14.47147
# [38]	validation-rmse:14.47076
# [39]	validation-rmse:14.47126
# [40]	validation-rmse:14.47081
# [41]	validation-rmse:14.47095
# [42]	validation-rmse:14.47010
# [43]	validation-rmse:14.46984
# [44]	validation-rmse:14.46845
# [45]	validation-rmse:14.46782
# [46]	validation-rmse:14.46796
# [47]	validation-rmse:14.46600
# [48]	validation-rmse:14.46588
# [49]	validation-rmse:14.46553
# [50]	validation-rmse:14.46490
# [51]	validation-rmse:14.46289
# [52]	validation-rmse:14.46247
# [53]	validation-rmse:14.46231
# [54]	validation-rmse:14.46219
# [55]	validation-rmse:14.46121
# [56]	validation-rmse:14.46131
# [57]	validation-rmse:14.46099
# [58]	validation-rmse:14.46075
# [18:05:57] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:20.56696
# [1]	validation-rmse:18.17146
# [2]	validation-rmse:16.67759
# [3]	validation-rmse:15.58485
# [4]	validation-rmse:15.06741
# [5]	validation-rmse:14.77707
# [6]	validation-rmse:14.53940
# [7]	validation-rmse:14.47425
# [8]	validation-rmse:14.44283
# [9]	validation-rmse:14.43158
# [10]	validation-rmse:14.43013
# [11]	validation-rmse:14.44370
# [12]	validation-rmse:14.45551
# [13]	validation-rmse:14.46313
# [14]	validation-rmse:14.47018
# [15]	validation-rmse:14.47631
# [16]	validation-rmse:14.48862
# [17]	validation-rmse:14.49304
# [18]	validation-rmse:14.49610
# [19]	validation-rmse:14.49855
# [20]	validation-rmse:14.50424
# [21]	validation-rmse:14.50594
# [22]	validation-rmse:14.50670
# [23]	validation-rmse:14.50724
# [24]	validation-rmse:14.50810
# [25]	validation-rmse:14.50799
# [26]	validation-rmse:14.50719
# [27]	validation-rmse:14.50824
# [28]	validation-rmse:14.50791
# [29]	validation-rmse:14.51013
# [30]	validation-rmse:14.50833
# [31]	validation-rmse:14.50463
# [32]	validation-rmse:14.50368
# [33]	validation-rmse:14.50335
# [34]	validation-rmse:14.50353
# [35]	validation-rmse:14.50321
# [36]	validation-rmse:14.50288
# [37]	validation-rmse:14.50388
# [38]	validation-rmse:14.50400
# [39]	validation-rmse:14.50303
# [40]	validation-rmse:14.50226
# [41]	validation-rmse:14.50104
# [42]	validation-rmse:14.49885
# [43]	validation-rmse:14.49942
# [44]	validation-rmse:14.49800
# [45]	validation-rmse:14.49716
# [46]	validation-rmse:14.49683
# [47]	validation-rmse:14.49542
# [48]	validation-rmse:14.49476
# [49]	validation-rmse:14.49286
# [50]	validation-rmse:14.49191
# [51]	validation-rmse:14.49077
# [52]	validation-rmse:14.49028
# [53]	validation-rmse:14.48983
# [54]	validation-rmse:14.49011
# [55]	validation-rmse:14.48987
# [56]	validation-rmse:14.48948
# [57]	validation-rmse:14.48931
# [58]	validation-rmse:14.48960
# [59]	validation-rmse:14.48936
# [18:08:59] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:18.89079
# [1]	validation-rmse:16.41135
# [2]	validation-rmse:15.18143
# [3]	validation-rmse:14.64336
# [4]	validation-rmse:14.50110
# [5]	validation-rmse:14.44836
# [6]	validation-rmse:14.43118
# [7]	validation-rmse:14.43049
# [8]	validation-rmse:14.43471
# [9]	validation-rmse:14.43960
# [10]	validation-rmse:14.44102
# [11]	validation-rmse:14.44429
# [12]	validation-rmse:14.44582
# [13]	validation-rmse:14.44855
# [14]	validation-rmse:14.44815
# [15]	validation-rmse:14.44792
# [16]	validation-rmse:14.44768
# [17]	validation-rmse:14.44949
# [18]	validation-rmse:14.44904
# [19]	validation-rmse:14.45038
# [20]	validation-rmse:14.44982
# [21]	validation-rmse:14.45012
# [22]	validation-rmse:14.45001
# [23]	validation-rmse:14.45168
# [24]	validation-rmse:14.45114
# [25]	validation-rmse:14.45227
# [26]	validation-rmse:14.45348
# [27]	validation-rmse:14.45289
# [28]	validation-rmse:14.45182
# [29]	validation-rmse:14.45969
# [30]	validation-rmse:14.45896
# [31]	validation-rmse:14.45812
# [32]	validation-rmse:14.45833
# [33]	validation-rmse:14.45903
# [34]	validation-rmse:14.45922
# [35]	validation-rmse:14.45826
# [36]	validation-rmse:14.45775
# [37]	validation-rmse:14.45674
# [38]	validation-rmse:14.45697
# [39]	validation-rmse:14.45620
# [40]	validation-rmse:14.45638
# [41]	validation-rmse:14.45758
# [42]	validation-rmse:14.45750
# [43]	validation-rmse:14.45846
# [44]	validation-rmse:14.45854
# [45]	validation-rmse:14.45848
# [46]	validation-rmse:14.45802
# [47]	validation-rmse:14.45830
# [48]	validation-rmse:14.45838
# [49]	validation-rmse:14.45799
# [50]	validation-rmse:14.45926
# [51]	validation-rmse:14.45947
# [52]	validation-rmse:14.45899
# [53]	validation-rmse:14.45808
# [54]	validation-rmse:14.46379
# [55]	validation-rmse:14.46346
# [56]	validation-rmse:14.46370
# [57]	validation-rmse:14.46295
# [18:09:13] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:22.67850
# [1]	validation-rmse:21.71934
# [2]	validation-rmse:20.83454
# [3]	validation-rmse:20.07856
# [4]	validation-rmse:19.35942
# [5]	validation-rmse:18.74915
# [6]	validation-rmse:18.21692
# [7]	validation-rmse:17.67918
# [8]	validation-rmse:17.26510
# [9]	validation-rmse:16.84164
# [10]	validation-rmse:16.51614
# [11]	validation-rmse:16.18743
# [12]	validation-rmse:15.94550
# [13]	validation-rmse:15.73052
# [14]	validation-rmse:15.54504
# [15]	validation-rmse:15.35023
# [16]	validation-rmse:15.21183
# [17]	validation-rmse:15.09246
# [18]	validation-rmse:14.96635
# [19]	validation-rmse:14.85866
# [20]	validation-rmse:14.78583
# [21]	validation-rmse:14.72447
# [22]	validation-rmse:14.67124
# [23]	validation-rmse:14.61479
# [24]	validation-rmse:14.57884
# [25]	validation-rmse:14.54854
# [26]	validation-rmse:14.51533
# [27]	validation-rmse:14.49558
# [28]	validation-rmse:14.47986
# [29]	validation-rmse:14.46879
# [30]	validation-rmse:14.45804
# [31]	validation-rmse:14.45087
# [32]	validation-rmse:14.44075
# [33]	validation-rmse:14.43701
# [34]	validation-rmse:14.43234
# [35]	validation-rmse:14.43089
# [36]	validation-rmse:14.43006
# [37]	validation-rmse:14.42975
# [38]	validation-rmse:14.42999
# [39]	validation-rmse:14.43059
# [40]	validation-rmse:14.43138
# [41]	validation-rmse:14.43304
# [42]	validation-rmse:14.43439
# [43]	validation-rmse:14.43671
# [44]	validation-rmse:14.43828
# [45]	validation-rmse:14.43991
# [46]	validation-rmse:14.44155
# [47]	validation-rmse:14.44343
# [48]	validation-rmse:14.44492
# [49]	validation-rmse:14.44769
# [50]	validation-rmse:14.44951
# [51]	validation-rmse:14.45089
# [52]	validation-rmse:14.45262
# [53]	validation-rmse:14.45424
# [54]	validation-rmse:14.45533
# [55]	validation-rmse:14.45669
# [56]	validation-rmse:14.45808
# [57]	validation-rmse:14.46046
# ...
# [33]	validation-rmse:14.45901
# [34]	validation-rmse:14.45878
# [35]	validation-rmse:14.45774
# [36]	validation-rmse:14.45775
# [37]	validation-rmse:14.45786
# [38]	validation-rmse:14.45771
# [39]	validation-rmse:14.45781
# [40]	validation-rmse:14.45729
# [41]	validation-rmse:14.45722
# [42]	validation-rmse:14.45707
# [43]	validation-rmse:14.45702
# [44]	validation-rmse:14.45690
# [45]	validation-rmse:14.45560
# [46]	validation-rmse:14.45567
# [47]	validation-rmse:14.45567
# [48]	validation-rmse:14.45551
# [49]	validation-rmse:14.45545
# [50]	validation-rmse:14.45547
# [51]	validation-rmse:14.45543
# [52]	validation-rmse:14.45541
# [19:25:18] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:14.50006
# [1]	validation-rmse:14.51448
# [2]	validation-rmse:14.51576
# [3]	validation-rmse:14.51288
# [4]	validation-rmse:14.51043
# [5]	validation-rmse:14.50770
# [6]	validation-rmse:14.50236
# [7]	validation-rmse:14.50235
# [8]	validation-rmse:14.50236
# [9]	validation-rmse:14.50247
# [10]	validation-rmse:14.50363
# [11]	validation-rmse:14.50356
# [12]	validation-rmse:14.50361
# [13]	validation-rmse:14.50363
# [14]	validation-rmse:14.50360
# [15]	validation-rmse:14.50358
# [16]	validation-rmse:14.50362
# [17]	validation-rmse:14.50371
# [18]	validation-rmse:14.50369
# [19]	validation-rmse:14.50375
# [20]	validation-rmse:14.50346
# [21]	validation-rmse:14.50337
# [22]	validation-rmse:14.50342
# [23]	validation-rmse:14.50344
# [24]	validation-rmse:14.50342
# [25]	validation-rmse:14.50344
# [26]	validation-rmse:14.50344
# [27]	validation-rmse:14.50346
# [28]	validation-rmse:14.50400
# [29]	validation-rmse:14.50398
# [30]	validation-rmse:14.50402
# [31]	validation-rmse:14.50405
# [32]	validation-rmse:14.50410
# [33]	validation-rmse:14.50474
# [34]	validation-rmse:14.50475
# [35]	validation-rmse:14.50471
# [36]	validation-rmse:14.50475
# [37]	validation-rmse:14.50477
# [38]	validation-rmse:14.50477
# [39]	validation-rmse:14.50480
# [40]	validation-rmse:14.50536
# [41]	validation-rmse:14.50530
# [42]	validation-rmse:14.50529
# [43]	validation-rmse:14.50537
# [44]	validation-rmse:14.50537
# [45]	validation-rmse:14.50537
# [46]	validation-rmse:14.50536
# [47]	validation-rmse:14.50536
# [48]	validation-rmse:14.50539
# [49]	validation-rmse:14.50538
# [19:27:35] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:20.16332
# [1]	validation-rmse:17.65417
# [2]	validation-rmse:16.23926
# [3]	validation-rmse:15.40230
# [4]	validation-rmse:14.96354
# [5]	validation-rmse:14.71729
# [6]	validation-rmse:14.51312
# [7]	validation-rmse:14.46290
# [8]	validation-rmse:14.43943
# [9]	validation-rmse:14.43013
# [10]	validation-rmse:14.43519
# [11]	validation-rmse:14.44106
# [12]	validation-rmse:14.44660
# [13]	validation-rmse:14.45086
# [14]	validation-rmse:14.45651
# [15]	validation-rmse:14.46545
# [16]	validation-rmse:14.46806
# [17]	validation-rmse:14.47074
# [18]	validation-rmse:14.47159
# [19]	validation-rmse:14.47038
# [20]	validation-rmse:14.47061
# [21]	validation-rmse:14.47138
# [22]	validation-rmse:14.47422
# [23]	validation-rmse:14.47434
# [24]	validation-rmse:14.47433
# [25]	validation-rmse:14.47363
# [26]	validation-rmse:14.47547
# [27]	validation-rmse:14.47208
# [28]	validation-rmse:14.47120
# [29]	validation-rmse:14.47132
# [30]	validation-rmse:14.47094
# [31]	validation-rmse:14.47078
# [32]	validation-rmse:14.47061
# [33]	validation-rmse:14.46782
# [34]	validation-rmse:14.46701
# [35]	validation-rmse:14.46654
# [36]	validation-rmse:14.46546
# [37]	validation-rmse:14.46481
# [38]	validation-rmse:14.46264
# [39]	validation-rmse:14.46212
# [40]	validation-rmse:14.45992
# [41]	validation-rmse:14.45972
# [42]	validation-rmse:14.45961
# [43]	validation-rmse:14.45918
# [44]	validation-rmse:14.45901
# [45]	validation-rmse:14.45845
# [46]	validation-rmse:14.45826
# [47]	validation-rmse:14.45772
# [48]	validation-rmse:14.45660
# [49]	validation-rmse:14.45647
# [50]	validation-rmse:14.45438
# [51]	validation-rmse:14.45401
# [52]	validation-rmse:14.45388
# [53]	validation-rmse:14.45378
# [54]	validation-rmse:14.45378
# [55]	validation-rmse:14.45195
# [56]	validation-rmse:14.45196
# [57]	validation-rmse:14.45201
# [58]	validation-rmse:14.45176
# [19:29:08] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:17.76828
# [1]	validation-rmse:15.08949
# [2]	validation-rmse:14.56043
# [3]	validation-rmse:14.43025
# [4]	validation-rmse:14.44942
# [5]	validation-rmse:14.47174
# [6]	validation-rmse:14.48927
# [7]	validation-rmse:14.50255
# [8]	validation-rmse:14.51144
# [9]	validation-rmse:14.51525
# [10]	validation-rmse:14.51520
# [11]	validation-rmse:14.51837
# [12]	validation-rmse:14.51718
# [13]	validation-rmse:14.51761
# [14]	validation-rmse:14.51132
# [15]	validation-rmse:14.50446
# [16]	validation-rmse:14.49420
# [17]	validation-rmse:14.49023
# [18]	validation-rmse:14.48902
# [19]	validation-rmse:14.48851
# [20]	validation-rmse:14.48879
# [21]	validation-rmse:14.48768
# [22]	validation-rmse:14.48763
# [23]	validation-rmse:14.48712
# [24]	validation-rmse:14.48727
# [25]	validation-rmse:14.48607
# [26]	validation-rmse:14.48589
# [27]	validation-rmse:14.48597
# [28]	validation-rmse:14.48592
# [29]	validation-rmse:14.48568
# [30]	validation-rmse:14.48545
# [31]	validation-rmse:14.48538
# [32]	validation-rmse:14.48522
# [33]	validation-rmse:14.48511
# [34]	validation-rmse:14.48502
# [35]	validation-rmse:14.48489
# [36]	validation-rmse:14.48485
# [37]	validation-rmse:14.48479
# [38]	validation-rmse:14.48461
# [39]	validation-rmse:14.48391
# [40]	validation-rmse:14.48389
# [41]	validation-rmse:14.48377
# [42]	validation-rmse:14.48348
# [43]	validation-rmse:14.48229
# [44]	validation-rmse:14.48216
# [45]	validation-rmse:14.48216
# [46]	validation-rmse:14.48203
# [47]	validation-rmse:14.48199
# [48]	validation-rmse:14.48191
# [49]	validation-rmse:14.48182
# [50]	validation-rmse:14.48175
# [51]	validation-rmse:14.48178
# [52]	validation-rmse:14.48182
# [53]	validation-rmse:14.48182
# 100%|██████████| 50/50 [1:46:23<00:00, 127.67s/trial, best loss: 14.434830071276503]

# %% [markdown]
# ### Model Selection
#
# We have selected run `09923bbad64045ca837a1656254ce756` in MLflow experiment as our model

# %%
# Hyperparameter for run 09923bbad64045ca837a1656254ce756

params = {
    'max_depth': 4,
    'learning_rate': 0.14493221791716185,
    'reg_alpha': 0.012153110171030913,
    'reg_lambda': 0.017881159785939696,
    'min_child_weight': 0.674864917045824,
    'objective': 'reg:linear',
    'seed': 42
}

# %% [markdown]
# #### `Autolog`

# %%
# Train the model with the selected params and autolog 
mlflow.xgboost.autolog(disable=False)

with mlflow.start_run():
    booster = xgb.train(
                params=params,
                dtrain=train,
                num_boost_round=1000,
                evals=[(valid, 'validation')],
                early_stopping_rounds=50
            )
# Out:
# [08:25:57] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:21.51928
# [1]	validation-rmse:19.75349
# [2]	validation-rmse:18.37375
# [3]	validation-rmse:17.31223
# [4]	validation-rmse:16.47958
# [5]	validation-rmse:15.88425
# [6]	validation-rmse:15.44593
# [7]	validation-rmse:15.18472
# [8]	validation-rmse:14.91837
# [9]	validation-rmse:14.78518
# [10]	validation-rmse:14.64478
# [11]	validation-rmse:14.57900
# [12]	validation-rmse:14.53318
# [13]	validation-rmse:14.49797
# [14]	validation-rmse:14.47204
# [15]	validation-rmse:14.45054
# [16]	validation-rmse:14.44113
# [17]	validation-rmse:14.43616
# [18]	validation-rmse:14.43254
# [19]	validation-rmse:14.43052
# [20]	validation-rmse:14.42980
# [21]	validation-rmse:14.42992
# [22]	validation-rmse:14.43050
# [23]	validation-rmse:14.43129
# [24]	validation-rmse:14.43218
# [25]	validation-rmse:14.43268
# [26]	validation-rmse:14.43350
# [27]	validation-rmse:14.43428
# [28]	validation-rmse:14.43500
# [29]	validation-rmse:14.43576
# [30]	validation-rmse:14.44011
# [31]	validation-rmse:14.44078
# [32]	validation-rmse:14.44218
# [33]	validation-rmse:14.44254
# [34]	validation-rmse:14.44265
# [35]	validation-rmse:14.44270
# [36]	validation-rmse:14.44834
# [37]	validation-rmse:14.44862
# [38]	validation-rmse:14.44866
# [39]	validation-rmse:14.44913
# [40]	validation-rmse:14.44915
# [41]	validation-rmse:14.44897
# [42]	validation-rmse:14.44972
# [43]	validation-rmse:14.44964
# [44]	validation-rmse:14.44980
# [45]	validation-rmse:14.44971
# [46]	validation-rmse:14.44877
# [47]	validation-rmse:14.45375
# [48]	validation-rmse:14.45457
# [49]	validation-rmse:14.45436
# [50]	validation-rmse:14.45392
# [51]	validation-rmse:14.45355
# [52]	validation-rmse:14.45329
# [53]	validation-rmse:14.45402
# [54]	validation-rmse:14.45381
# [55]	validation-rmse:14.45362
# [56]	validation-rmse:14.45417
# [57]	validation-rmse:14.45382
# [58]	validation-rmse:14.45431
# [59]	validation-rmse:14.45405
# [60]	validation-rmse:14.45406
# [61]	validation-rmse:14.45388
# [62]	validation-rmse:14.45445
# [63]	validation-rmse:14.45447
# [64]	validation-rmse:14.45425
# [65]	validation-rmse:14.45477
# [66]	validation-rmse:14.45448
# [67]	validation-rmse:14.45446
# [68]	validation-rmse:14.45420
# [69]	validation-rmse:14.45460
# [70]	validation-rmse:14.45524
# 2022/05/31 08:26:13 WARNING mlflow.xgboost: Failed to infer model signature: could not sample data to infer model signature: please ensure that autologging is enabled before constructing the dataset.

# %% [markdown]
# ##### Using Saved `Autolog` MLflow Model

# %%
logged_model = 'runs:/01d97a61959f42ba964175e922ee9573/model'

# Load model as a PyFuncModel.
loaded_model = mlflow.pyfunc.load_model(logged_model)

loaded_model
# Out:
# [10:10:29] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# mlflow.pyfunc.loaded_model:
#   artifact_path: model
#   flavor: mlflow.xgboost
#   run_id: 01d97a61959f42ba964175e922ee9573

# %%
loaded_model.predict(X_val)
# Out:
# array([20.216328, 20.216328, 20.216328, ..., 20.216328, 20.216328,
#        20.216328], dtype=float32)

# %%
# Load model as XGBmodel
xgb_model = mlflow.xgboost.load_model(logged_model)
xgb_model
# Out:
# [10:23:46] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.

# %%
xgb_model.predict(valid)
# Out:
# array([20.216328, 20.216328, 20.216328, ..., 20.216328, 20.216328,
#        20.216328], dtype=float32)

# %% [markdown]
# ### Logging Models with MLflow

# %%
# Adapting from our previous XGBoost model, we will save the artifact into MLflow and log the parameters manually
# We will also log the DictVectorizer preprocessor as an artifact

# Turn off autolog
mlflow.xgboost.autolog(disable=True)


with mlflow.start_run():
    # Hyperparameter for run 09923bbad64045ca837a1656254ce756
    params = {
        'max_depth': 4,
        'learning_rate': 0.14493221791716185,
        'reg_alpha': 0.012153110171030913,
        'reg_lambda': 0.017881159785939696,
        'min_child_weight': 0.674864917045824,
        'objective': 'reg:linear',
        'seed': 42
    }

    mlflow.log_params(params)
    

    booster = xgb.train(
                params=params,
                dtrain=train,
                num_boost_round=1000,
                evals=[(valid, 'validation')],
                early_stopping_rounds=50
            )

    # get the y_pred from X_train
    y_pred = booster.predict(valid)

    # get RMSE and record on mlflow
    rmse = round(mean_squared_error(y_val, y_pred, squared=False),2)
    print("RMSE for training data:", rmse)
    mlflow.log_metric("rmse", rmse)

    # log xgboost model to mlflow
    mlflow.xgboost.log_model(booster, artifact_path="models_mlflow")

    # log the preprocessor DictVectorizer
    with open("models/preprocessor.bin", "wb") as f_out:
        pickle.dump(dv, f_out)
    
    mlflow.log_artifact("models/preprocessor.bin", artifact_path="preprocessor")
# Out:
# [12:22:26] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# [0]	validation-rmse:21.51928
# [1]	validation-rmse:19.75349
# [2]	validation-rmse:18.37375
# [3]	validation-rmse:17.31223
# [4]	validation-rmse:16.47958
# [5]	validation-rmse:15.88425
# [6]	validation-rmse:15.44593
# [7]	validation-rmse:15.18472
# [8]	validation-rmse:14.91837
# [9]	validation-rmse:14.78518
# [10]	validation-rmse:14.64478
# [11]	validation-rmse:14.57900
# [12]	validation-rmse:14.53318
# [13]	validation-rmse:14.49797
# [14]	validation-rmse:14.47204
# [15]	validation-rmse:14.45054
# [16]	validation-rmse:14.44113
# [17]	validation-rmse:14.43616
# [18]	validation-rmse:14.43254
# [19]	validation-rmse:14.43052
# [20]	validation-rmse:14.42980
# [21]	validation-rmse:14.42992
# [22]	validation-rmse:14.43050
# [23]	validation-rmse:14.43129
# [24]	validation-rmse:14.43218
# [25]	validation-rmse:14.43268
# [26]	validation-rmse:14.43350
# [27]	validation-rmse:14.43428
# [28]	validation-rmse:14.43500
# [29]	validation-rmse:14.43576
# [30]	validation-rmse:14.44011
# [31]	validation-rmse:14.44078
# [32]	validation-rmse:14.44218
# [33]	validation-rmse:14.44254
# [34]	validation-rmse:14.44265
# [35]	validation-rmse:14.44270
# [36]	validation-rmse:14.44834
# [37]	validation-rmse:14.44862
# [38]	validation-rmse:14.44866
# [39]	validation-rmse:14.44913
# [40]	validation-rmse:14.44915
# [41]	validation-rmse:14.44897
# [42]	validation-rmse:14.44972
# [43]	validation-rmse:14.44964
# [44]	validation-rmse:14.44980
# [45]	validation-rmse:14.44971
# [46]	validation-rmse:14.44877
# [47]	validation-rmse:14.45375
# [48]	validation-rmse:14.45457
# [49]	validation-rmse:14.45436
# [50]	validation-rmse:14.45392
# [51]	validation-rmse:14.45355
# [52]	validation-rmse:14.45329
# [53]	validation-rmse:14.45402
# [54]	validation-rmse:14.45381
# [55]	validation-rmse:14.45362
# [56]	validation-rmse:14.45417
# [57]	validation-rmse:14.45382
# [58]	validation-rmse:14.45431
# [59]	validation-rmse:14.45405
# [60]	validation-rmse:14.45406
# [61]	validation-rmse:14.45388
# [62]	validation-rmse:14.45445
# [63]	validation-rmse:14.45447
# [64]	validation-rmse:14.45425
# [65]	validation-rmse:14.45477
# [66]	validation-rmse:14.45448
# [67]	validation-rmse:14.45446
# [68]	validation-rmse:14.45420
# [69]	validation-rmse:14.45460
# [70]	validation-rmse:14.45524
# RMSE for training data: 14.46

# %% [markdown]
# #### Prediction

# %%
logged_model = 'runs:/237dc915805441e8bfe958044ede7b18/models_mlflow'

# Load model as a xgboost.
xgb_model = mlflow.xgboost.load_model(logged_model)

# Prediction
y_valid = xgb_model.predict(valid) # using DMatrix-typed validation data

y_valid
# Out:
# [14:48:42] WARNING: ../src/objective/regression_obj.cu:203: reg:linear is now deprecated in favor of reg:squarederror.
# array([20.216328, 20.216328, 20.216328, ..., 20.216328, 20.216328,
#        20.216328], dtype=float32)

# %% [markdown]
# ## Alternate Models
#
# Let's retrain the model using different architectures so that we can have different versions. We will use `mlflow.*.autolog()` for the logging of our models

# %% [markdown]
# #### `Lasso`

# %%
# serialize Preprocessor
with open("models/preprocessor.bin", "wb") as f_out:
    pickle.dump(dv, f_out)

# %%
# start logging with mlflow
with mlflow.start_run():
    
    mlflow.sklearn.autolog(log_post_training_metrics=False, 
                           serialization_format=mlflow.sklearn.SERIALIZATION_FORMAT_PICKLE)

    # set tag for mlflow
    mlflow.set_tag("developer", "Bengsoon")
    mlflow.set_tag("model", "lasso")

    # set data path param
    mlflow.log_param("train-data-path", "./data/fhv_tripdata_2021-01.parquet")
    mlflow.log_param("valid-data-path", "./data/fhv_tripdata_2021-02.parquet")

    # set hyper parameter for Lasso
    alpha = 0.01
    mlflow.log_param("alpha", alpha)
    lr = Lasso(alpha = alpha)
    
    # train the model
    lr.fit(X_train, y_train)

    # get the y_pred from X_train
    y_pred = lr.predict(X_val)

    # get RMSE and record on mlflow
    rmse = round(mean_squared_error(y_val, y_pred, squared=False),2)
    print("RMSE for training data:", rmse)
    mlflow.log_metric("rmse", rmse)
    
    # log preprocessor as artifact
    mlflow.log_artifact("models/preprocessor.bin", artifact_path="preprocessor")
# Out:
# 2022/06/01 08:30:30 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of sklearn. If you encounter errors during autologging, try upgrading / downgrading sklearn to a supported version, or try upgrading MLflow.
# 2022/06/01 08:30:38 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: The following failures occurred while performing one or more logging operations: [MlflowException('Failed to perform one or more operations on the run with ID fba889f739f84551a65883aa541e0dfe. Failed operations: [MlflowException("Changing param values is not allowed. Params were already logged=\'[{\'key\': \'copy_X\', \'old_value\': None, \'new_value\': \'True\'}, {\'key\': \'fit_intercept\', \'old_value\': None, \'new_value\': \'True\'}, {\'key\': \'max_iter\', \'old_value\': None, \'new_value\': \'1000\'}, {\'key\': \'normalize\', \'old_value\': None, \'new_value\': \'deprecated\'}, {\'key\': \'positive\', \'old_value\': None, \'new_value\': \'False\'}, {\'key\': \'precompute\', \'old_value\': None, \'new_value\': \'False\'}, {\'key\': \'random_state\', \'old_value\': None, \'new_value\': \'None\'}, {\'key\': \'selection\', \'old_value\': None, \'new_value\': \'cyclic\'}, {\'key\': \'tol\', \'old_value\': None, \'new_value\': \'0.0001\'}, {\'key\': \'warm_start\', \'old_value\': None, \'new_value\': \'False\'}]\' for run ID=\'fba889f739f84551a65883aa541e0dfe\'.")]')]
# RMSE for training data: 14.51

# %% [markdown]
# #### `GradientBoostingRegressor`

# %%
# start logging with mlflow
with mlflow.start_run():
    
    mlflow.sklearn.autolog(log_post_training_metrics=False, 
                           serialization_format=mlflow.sklearn.SERIALIZATION_FORMAT_PICKLE)

    # set tag for mlflow
    mlflow.set_tag("developer", "Bengsoon")
    mlflow.set_tag("model", "gradient_boosting_regressor")

    # set data path param
    mlflow.log_param("train-data-path", "./data/fhv_tripdata_2021-01.parquet")
    mlflow.log_param("valid-data-path", "./data/fhv_tripdata_2021-02.parquet")

    # set GradientBoostingRegressor's params
    params = {"learning_rate": 0.1, 
              "n_estimators": 100,
              "min_samples_split": 2,
              "max_depth": 3
              }
    gbr = GradientBoostingRegressor(**params)
    mlflow.log_params(params)

    # train the model
    gbr.fit(X_train, y_train)

    # get the y_pred from X_val
    y_pred = gbr.predict(X_val)

    # get RMSE and record on mlflow
    rmse = round(mean_squared_error(y_val, y_pred, squared=False),2)
    print("RMSE for training data:", rmse)
    mlflow.log_metric("rmse", rmse)
    
    # log preprocessor as artifact
    mlflow.log_artifact("models/preprocessor.bin", artifact_path="preprocessor")
# Out:
# 2022/06/01 08:30:55 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of sklearn. If you encounter errors during autologging, try upgrading / downgrading sklearn to a supported version, or try upgrading MLflow.
# 2022/06/01 08:32:09 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: The following failures occurred while performing one or more logging operations: [MlflowException('Failed to perform one or more operations on the run with ID 19f229fd72774edcbedbd126fb2e922d. Failed operations: [MlflowException("Changing param values is not allowed. Params were already logged=\'[{\'key\': \'alpha\', \'old_value\': None, \'new_value\': \'0.9\'}, {\'key\': \'ccp_alpha\', \'old_value\': None, \'new_value\': \'0.0\'}, {\'key\': \'criterion\', \'old_value\': None, \'new_value\': \'friedman_mse\'}, {\'key\': \'init\', \'old_value\': None, \'new_value\': \'None\'}, {\'key\': \'loss\', \'old_value\': None, \'new_value\': \'squared_error\'}, {\'key\': \'max_features\', \'old_value\': None, \'new_value\': \'None\'}, {\'key\': \'max_leaf_nodes\', \'old_value\': None, \'new_value\': \'None\'}, {\'key\': \'min_impurity_decrease\', \'old_value\': None, \'new_value\': \'0.0\'}, {\'key\': \'min_samples_leaf\', \'old_value\': None, \'new_value\': \'1\'}, {\'key\': \'min_weight_fraction_leaf\', \'old_value\': None, \'new_value\': \'0.0\'}, {\'key\': \'n_iter_no_change\', \'old_value\': None, \'new_value\': \'None\'}, {\'key\': \'random_state\', \'old_value\': None, \'new_value\': \'None\'}, {\'key\': \'subsample\', \'old_value\': None, \'new_value\': \'1.0\'}, {\'key\': \'tol\', \'old_value\': None, \'new_value\': \'0.0001\'}, {\'key\': \'validation_fraction\', \'old_value\': None, \'new_value\': \'0.1\'}, {\'key\': \'verbose\', \'old_value\': None, \'new_value\': \'0\'}, {\'key\': \'warm_start\', \'old_value\': None, \'new_value\': \'False\'}]\' for run ID=\'19f229fd72774edcbedbd126fb2e922d\'.")]')]
# RMSE for training data: 14.45

# %% [markdown]
# #### `ElasticNet`

# %%
# start logging with mlflow
with mlflow.start_run():
    
    mlflow.sklearn.autolog(log_post_training_metrics=False, 
                           serialization_format=mlflow.sklearn.SERIALIZATION_FORMAT_PICKLE)

    # set tag for mlflow
    mlflow.set_tag("developer", "Bengsoon")
    mlflow.set_tag("model", "elasticnet")

    # set data path param
    mlflow.log_param("train-data-path", "./data/fhv_tripdata_2021-01.parquet")
    mlflow.log_param("valid-data-path", "./data/fhv_tripdata_2021-02.parquet")

    # set GradientBoostingRegressor's params
    alpha = 1.0
    enr = ElasticNet(alpha=alpha)
    mlflow.log_param("alpha", alpha)

    # train the model
    enr.fit(X_train, y_train)

    # get the y_pred from X_val
    y_pred = enr.predict(X_val)

    # get RMSE and record on mlflow
    rmse = round(mean_squared_error(y_val, y_pred, squared=False),2)
    print("RMSE for training data:", rmse)
    mlflow.log_metric("rmse", rmse)
    
    # log preprocessor as artifact
    mlflow.log_artifact("models/preprocessor.bin", artifact_path="preprocessor")
# Out:
# 2022/06/01 08:32:11 WARNING mlflow.utils.autologging_utils: You are using an unsupported version of sklearn. If you encounter errors during autologging, try upgrading / downgrading sklearn to a supported version, or try upgrading MLflow.
# 2022/06/01 08:32:14 WARNING mlflow.utils.autologging_utils: Encountered unexpected error during sklearn autologging: The following failures occurred while performing one or more logging operations: [MlflowException('Failed to perform one or more operations on the run with ID 6e927d485a104a5991d9c3377d263a93. Failed operations: [MlflowException("Changing param values is not allowed. Params were already logged=\'[{\'key\': \'copy_X\', \'old_value\': None, \'new_value\': \'True\'}, {\'key\': \'fit_intercept\', \'old_value\': None, \'new_value\': \'True\'}, {\'key\': \'l1_ratio\', \'old_value\': None, \'new_value\': \'0.5\'}, {\'key\': \'max_iter\', \'old_value\': None, \'new_value\': \'1000\'}, {\'key\': \'normalize\', \'old_value\': None, \'new_value\': \'deprecated\'}, {\'key\': \'positive\', \'old_value\': None, \'new_value\': \'False\'}, {\'key\': \'precompute\', \'old_value\': None, \'new_value\': \'False\'}, {\'key\': \'random_state\', \'old_value\': None, \'new_value\': \'None\'}, {\'key\': \'selection\', \'old_value\': None, \'new_value\': \'cyclic\'}, {\'key\': \'tol\', \'old_value\': None, \'new_value\': \'0.0001\'}, {\'key\': \'warm_start\', \'old_value\': None, \'new_value\': \'False\'}]\' for run ID=\'6e927d485a104a5991d9c3377d263a93\'.")]')]
# RMSE for training data: 14.47

# %% [markdown]
# ## Using MLflow Client

# %%
from mlflow.tracking import MlflowClient

# %%
# instantiate the client

MLFLOW_TRACKING_URI = "sqlite:///mlflow.db"
client = MlflowClient(tracking_uri=MLFLOW_TRACKING_URI)

# %%
# we can create experiments
client.create_experiment(name="test")
# Out:
# '4'

# %%
# list experiments
client.list_experiments()
# Out:
# [<Experiment: artifact_location='./mlruns/2', experiment_id='2', lifecycle_stage='active', name='nyc-taxi-experiment', tags={}>,
#  <Experiment: artifact_location='./mlruns/4', experiment_id='4', lifecycle_stage='active', name='test', tags={}>]

# %% [markdown]
# ### Get the runs in `nyc-taxi-experiment`

# %%
from mlflow.entities import ViewType

runs = client.search_runs(
    experiment_ids= "2",
    filter_string="",
    run_view_type=ViewType.ACTIVE_ONLY,
    max_results=5,
    order_by=["metrics.rmse ASC"]
)

# %%
runs[:2]
# Out:
# [<Run: data=<RunData: metrics={'rmse': 14.434830071276503}, params={'learning_rate': '0.4265314430554626',
#   'max_depth': '90',
#   'min_child_weight': '19.781075119943388',
#   'objective': 'reg:linear',
#   'reg_alpha': '0.07355580679915082',
#   'reg_lambda': '0.023586442422092634',
#   'seed': '42'}, tags={'mlflow.source.name': '/home/bengsoon/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'bengsoon',
#   'model': 'xgboost'}>, info=<RunInfo: artifact_uri='./mlruns/2/572b0ed57e3748ac965af939c28f3d0e/artifacts', end_time=1653561903802, experiment_id='2', lifecycle_stage='active', run_id='572b0ed57e3748ac965af939c28f3d0e', run_uuid='572b0ed57e3748ac965af939c28f3d0e', start_time=1653561788679, status='FINISHED', user_id='bengsoon'>>,
#  <Run: data=<RunData: metrics={'rmse': 14.436014044219164}, params={'learning_rate': '0.3903501367212693',
#   'max_depth': '87',
#   'min_child_weight': '18.341681221213463',
#   'objective': 'reg:linear',
#   'reg_alpha': '0.007256798864423147',
#   'reg_lambda': '0.03175516143518333',
#   'seed': '42'}, tags={'mlflow.source.name': '/home/bengsoon/anaconda3/envs/exp-tracking-env/lib/python3.9/site-packages/ipykernel_launcher.py',
#   'mlflow.source.type': 'LOCAL',
#   'mlflow.user': 'bengsoon',
#   'model': 'xgboost'}>, info=<RunInfo: artifact_uri='./mlruns/2/be2c1e01147c422fa40f9aca18025447/artifacts', end_time=1653561130898, experiment_id='2', lifecycle_stage='active', run_id='be2c1e01147c422fa40f9aca18025447', run_uuid='be2c1e01147c422fa40f9aca18025447', start_time=1653561023028, status='FINISHED', user_id='bengsoon'>>]

# %%
# the runs have a ton of information, but we can choose to only view the run_id and rmse
for run in runs:
    print(f"run id: {run.info.run_id}, rmse: {run.data.metrics['rmse']}")
# Out:
# run id: 572b0ed57e3748ac965af939c28f3d0e, rmse: 14.434830071276503
# run id: be2c1e01147c422fa40f9aca18025447, rmse: 14.436014044219164
# run id: ebb70531b3d348808e9c13bd801f335a, rmse: 14.436321257721108
# run id: 494b84cae6e84edb8e3caa51603c2318, rmse: 14.436641761102681
# run id: 1e835cd7d1544c01ac90901218a8757e, rmse: 14.44200357693116

# %%
runs[0].info.run_id
# Out:
# '572b0ed57e3748ac965af939c28f3d0e'

# %% [markdown]
# #### Register a new model

# %% [markdown]
# We will try to register the run `572b0ed57e3748ac965af939c28f3d0e` in the Model Registry.

# %%
# import and set up mlflow
import mlflow

mlflow.set_tracking_uri(MLFLOW_TRACKING_URI)

# %%
# set up variables
RUN_ID = "572b0ed57e3748ac965af939c28f3d0e"
MODEL_URI = f"runs:/{RUN_ID}/model"

# %% [markdown]
# But first let's ensure that the run has not been registered:

# %%
assert client.search_model_versions(f"run_id = '{RUN_ID}'") == [], "Run has been registered!"

# %%
mlflow.register_model(model_uri = MODEL_URI, name="nyctaxi_tripduration_regressor")
# Out:
# Registered model 'nyctaxi_tripduration_regressor' already exists. Creating a new version of this model...
# 2022/06/01 14:51:46 INFO mlflow.tracking._model_registry.client: Waiting up to 300 seconds for model version to finish creation.                     Model name: nyctaxi_tripduration_regressor, version 5
# Created version '5' of model 'nyctaxi_tripduration_regressor'.
# <ModelVersion: creation_timestamp=1654066306963, current_stage='None', description=None, last_updated_timestamp=1654066306963, name='nyctaxi_tripduration_regressor', run_id='572b0ed57e3748ac965af939c28f3d0e', run_link=None, source='./mlruns/2/572b0ed57e3748ac965af939c28f3d0e/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=5>

# %% [markdown]
# #### Transition Model

# %%
# get the latest versions
model_name = "nyctaxi_tripduration_regressor"
latest_versions = client.get_latest_versions(name=model_name)

for version in latest_versions:
    print(f"Version: {version.version}, Stage: {version.current_stage}")
# Out:
# Version: 1, Stage: Production
# Version: 4, Stage: Staging
# Version: 5, Stage: None

# %%
# transition version 5 to "Staging"
stage = "Staging"
version = 5

client.transition_model_version_stage(
    name = model_name,
    version = version,
    stage = stage,
    archive_existing_versions = False
)
# Out:
# <ModelVersion: creation_timestamp=1654066306963, current_stage='Staging', description=None, last_updated_timestamp=1654072597722, name='nyctaxi_tripduration_regressor', run_id='572b0ed57e3748ac965af939c28f3d0e', run_link=None, source='./mlruns/2/572b0ed57e3748ac965af939c28f3d0e/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=5>

# %%
from datetime import datetime
today = datetime.today().date()

# Change description of Version 5
client.update_model_version(
    name=model_name,
    version = version,
    description = f"Model version {version} transitioned to {stage} on {today}"
)
# Out:
# <ModelVersion: creation_timestamp=1654066306963, current_stage='Staging', description='Model version 5 transitioned to Staging on 2022-06-01', last_updated_timestamp=1654072851285, name='nyctaxi_tripduration_regressor', run_id='572b0ed57e3748ac965af939c28f3d0e', run_link=None, source='./mlruns/2/572b0ed57e3748ac965af939c28f3d0e/artifacts/model', status='READY', status_message=None, tags={}, user_id=None, version=5>

# %% [markdown]
# #### Promote Version 2 to `Production`
